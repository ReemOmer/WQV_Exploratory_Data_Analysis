# %%
# Importing libraries and resizing the plot
from MLModels2 import MLModels
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
features = ['106595_62619','106596_62619','106607_90860','167659_99067']
for i in features:
    # Cleaning and spliting the data into training/testing
    x_train, y_train, x_test, y_test,date_measurements = MLModels.data_clean_split(i)
    # Creating a list to add the model's results to
    y_predict = []
    # Adding MultiLayer Perceptron to the list
    y_predict.append(MLModels.MLP_model(x_train,y_train,x_test,y_test))
    # Adding Linear regression results to the list
    y_predict.append(MLModels.LR_model(x_train,y_train,x_test))
    # Adding Logistic regression results
    y_predict.append(MLModels.MOR_model(x_train,y_train,x_test))
    # Adding Decision Tree Regressor
    y_predict.append(MLModels.DTR_model(x_train,y_train,x_test))
    # Adding Deep Neural Networks
    y_predict.append(MLModels.DNN_model(x_train,y_train,x_test,MLModels.baseline_model)) 
    # Adding Autoregression
    AR_test,AR_predict=MLModels.AR_model(date_measurements)
    y_predict.append(AR_predict)
    # Plot actual vs predicted values for the models
    plt.figure(figsize=(16,10))
    MLModels.plot_model(y_test,AR_test,y_predict)
    # Finding the accuracy of each model
    MLModels.acc_model(y_test,AR_test,y_predict)
# Out:
# (2460, 18) (2460, 6)
# [['logistic' 'lbfgs' '9' '0.0726317578755911']]
# <function explained_variance_score at 0x7f5aeb7e58c8>
# MLP                            	 0.9746309133848504
# Linear Regression              	 0.9708769564307517
# Logistic Regression            	 0.9575752717161338
# Decision Tree Regressor        	 0.8840327921211614
# Deep Neural Networks           	 0.9644131246387765
# Autoregresstion                	 0.9975103860225362
#
#
# <function mean_absolute_error at 0x7f5aeb7e56a8>
# MLP                            	 0.19936617255454644
# Linear Regression              	 0.21639367251946354
# Logistic Regression            	 0.26818856770780536
# Decision Tree Regressor        	 0.4337669376693767
# Deep Neural Networks           	 0.23851755616767448
# Autoregresstion                	 0.08691666666666667
#
#
# <function mean_squared_error at 0x7f5aeb7e5730>
# MLP                            	 0.0726317578755911
# Linear Regression              	 0.08302138151405929
# Logistic Regression            	 0.12373846343016083
# Decision Tree Regressor        	 0.33170840108401073
# Deep Neural Networks           	 0.1064976143643271
# Autoregresstion                	 0.009077499999999999
#
#
# <function r2_score at 0x7f5aeb7e5950>
# MLP                            	 0.9744832693802744
# Linear Regression              	 0.97082824628205
# Logistic Regression            	 0.9566199033942205
# Decision Tree Regressor        	 0.8837237396039005
# Deep Neural Networks           	 0.9626249197168403
# Autoregresstion                	 0.9975037384150688
#
#
# (91, 18) (91, 6)
# [['relu' 'lbfgs' '9' '0.03342272806116061']]
# <function explained_variance_score at 0x7f5aeb7e58c8>
# MLP                            	 0.9966693471367702
# Linear Regression              	 0.9980751247079911
# Logistic Regression            	 0.9924888543159432
# Decision Tree Regressor        	 0.9159620964602248
# Deep Neural Networks           	 0.863204378019136
# Autoregresstion                	 0.9974801825057995
#
#
# <function mean_absolute_error at 0x7f5aeb7e56a8>
# MLP                            	 0.1618435245504463
# Linear Regression              	 0.12311895592769173
# Logistic Regression            	 0.20770873396774372
# Decision Tree Regressor        	 0.3284259259259259
# Deep Neural Networks           	 0.39531945492520376
# Autoregresstion                	 0.07370833333333332
#
#
# <function mean_squared_error at 0x7f5aeb7e5730>
# MLP                            	 0.03342272806116061
# Linear Regression              	 0.021008687554775196
# Logistic Regression            	 0.05733303661802976
# Decision Tree Regressor        	 0.18656388888888886
# Deep Neural Networks           	 0.326868912958477
# Autoregresstion                	 0.006840416666666667
#
#
# <function r2_score at 0x7f5aeb7e5950>
# MLP                            	 0.9800037300784767
# Linear Regression              	 0.987438554663329
# Logistic Regression            	 0.9654631169179523
# Decision Tree Regressor        	 0.8910020926003073
# Deep Neural Networks           	 0.8177499630072259
# Autoregresstion                	 0.9974769544818871
#
#
# (2283, 18) (2283, 6)
# [['identity' 'lbfgs' '9' '0.13978048822908906']]
# <function explained_variance_score at 0x7f5aeb7e58c8>
# MLP                            	 0.9558601553869659
# Linear Regression              	 0.9582247539385316
# Logistic Regression            	 0.6174833408829902
# Decision Tree Regressor        	 0.6302686881654624
# Deep Neural Networks           	 0.9442855932989839
# Autoregresstion                	 0.9853906032805115
#
#
# <function mean_absolute_error at 0x7f5aeb7e56a8>
# MLP                            	 0.19953580255187287
# Linear Regression              	 0.19067554407604562
# Logistic Regression            	 0.44386063528250164
# Decision Tree Regressor        	 0.49824561403508727
# Deep Neural Networks           	 0.2899408927437855
# Autoregresstion                	 0.029166666666666667
#
#
# <function mean_squared_error at 0x7f5aeb7e5730>
# MLP                            	 0.13978048822908906
# Linear Regression              	 0.13281019983993528
# Logistic Regression            	 1.2865845804570692
# Decision Tree Regressor        	 1.2321418128654966
# Deep Neural Networks           	 0.19781264598829051
# Autoregresstion                	 0.00366666666666667
#
#
# <function r2_score at 0x7f5aeb7e5950>
# MLP                            	 0.9550356649295478
# Linear Regression              	 0.957271440621207
# Logistic Regression            	 0.5881820520603268
# Decision Tree Regressor        	 0.605640198872687
# Deep Neural Networks           	 0.9364884443045177
# Autoregresstion                	 0.9853211009174312
#
#
# (75, 18) (75, 6)
# [['identity' 'lbfgs' '5' '0.12584110280065988']]
# <function explained_variance_score at 0x7f5aeb7e58c8>
# MLP                            	 0.8114769748903331
# Linear Regression              	 0.7969377063486577
# Logistic Regression            	 0.49991394610192885
# Decision Tree Regressor        	 0.4472845051219734
# Deep Neural Networks           	 0.7265248418208201
# Autoregresstion                	 0.9935307310800214
#
#
# <function mean_absolute_error at 0x7f5aeb7e56a8>
# MLP                            	 0.24617888937628277
# Linear Regression              	 0.2541357186014928
# Logistic Regression            	 0.3588069028742556
# Decision Tree Regressor        	 0.4436666666666667
# Deep Neural Networks           	 0.31324225940306977
# Autoregresstion                	 0.019208333333333334
#
#
# <function mean_squared_error at 0x7f5aeb7e5730>
# MLP                            	 0.12584110280065988
# Linear Regression              	 0.1347675193730972
# Logistic Regression            	 0.31930714344639527
# Decision Tree Regressor        	 0.31230555555555556
# Deep Neural Networks           	 0.18845916305393298
# Autoregresstion                	 0.0006070833333333335
#
#
# <function r2_score at 0x7f5aeb7e5950>
# MLP                            	 0.7939132672586501
# Linear Regression              	 0.7793355707084153
# Logistic Regression            	 0.4510885072352162
# Decision Tree Regressor        	 0.43155892517347755
# Deep Neural Networks           	 0.6695413687356324
# Autoregresstion                	 0.9934896035757284
